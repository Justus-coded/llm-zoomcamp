# %%
pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.6/983.6 kB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 kB 28.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 kB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 18.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.4/581.4 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 77.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 94.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 10.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 30.4 MB/s eta 0:00:00
# ...

# %%
pip install langchain_community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 30.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 8.2 MB/s eta 0:00:00
# ...

# %%
#pip install tiktoken==0.5.1

# %%
pip install langchain_openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.5/328.5 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 68.7 MB/s eta 0:00:00
# ...

# %%
pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 4.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
#pip install chromadb

# %%
# import required modules
import zipfile
import pandas as pd

# %%
df = pd.read_csv('/content/BusinessAnalyst.csv.zip')

# display dataset
df = df.iloc[:,2:]

# %%
len(df)
# Out:
# 4092

# %%
df1 = pd.read_csv('/content/DataAnalyst.csv.zip')

# display dataset
df1 = df1.iloc[:,1:]

# %%
df2 = pd.read_csv('/content/DataEngineer.csv.zip')

# display dataset
#df2 = df2.iloc[:,1:]

# %%
df3 = pd.read_csv('/content/DataScientist.csv.zip')

# display dataset
df3 = df3.iloc[:,2:]

# %%
df_new = pd.concat([pd.concat([pd.concat([df,df1],ignore_index=True),df2],ignore_index=True),df3],ignore_index=True)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12782 entries, 0 to 12781
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          12782 non-null  object
#  1   Salary Estimate    12782 non-null  object
#  2   Job Description    12782 non-null  object
#  3   Rating             12782 non-null  object
#  4   Company Name       12781 non-null  object
#  5   Location           12782 non-null  object
#  6   Headquarters       12782 non-null  object
#  7   Size               12782 non-null  object
#  8   Founded            12782 non-null  object
#  9   Type of ownership  12782 non-null  object
#  10  Industry           12782 non-null  object
#  11  Sector             12782 non-null  object
#  12  Revenue            12782 non-null  object
#  13  Competitors        12382 non-null  object
#  14  Easy Apply         12382 non-null  object
# dtypes: object(15)
# memory usage: 1.5+ MB

# %%
df_new.tail()
# Out:
#                                                Job Title  \
# 12777                                  AWS Data Engineer
# 12778                              Data Analyst â Junior
# 12779                   Security Analytics Data Engineer
# 12780                   Security Analytics Data Engineer
# 12781  Patient Safety Physician or Safety Scientist -...
#
#                    Salary Estimate  \
# 12777  $55K-$112K (Glassdoor est.)
# 12778  $55K-$112K (Glassdoor est.)
# 12779  $55K-$112K (Glassdoor est.)
# 12780  $55K-$112K (Glassdoor est.)
# 12781  $55K-$112K (Glassdoor est.)
#
#                                          Job Description Rating  \
# 12777  About Us\n\nTachyon Technologies is a Digital ...    4.4
# 12778  Job description\nInterpret data, analyze resul...    5.0
# 12779  Job DescriptionThe Security Analytics Data Eng...    3.8
# 12780  The Security Analytics Data Engineer will inte...    4.0
# 12781  Help us transform patients' lives.\nAt UCB, we...    3.7
#
# ...

# %%
df_new1 = df_new.copy()

# %%
# split the Name column into two columns
df_new1[['Company Name','Ratings']] = df_new1['Company Name'].str.split('\n',expand=True)

# %%
# split the Name column into two columns
df_new1[['Salary Estimate','website']] = df_new1['Salary Estimate'].str.split('(',expand=True)

# %%
df_new1.head()
# Out:
#                                           Job Title Salary Estimate  \
# 0  Business Analyst - Clinical & Logistics Platform     $56K-$102K
# 1                                  Business Analyst     $56K-$102K
# 2                                      Data Analyst     $56K-$102K
# 3   Information Security Analyst, Incident Response     $56K-$102K
# 4                     Analyst - FP&A Global Revenue     $56K-$102K
#
#                                      Job Description Rating  \
# 0  Company Overview\n\n\nAt Memorial Sloan Ketter...    3.9
# 1  We are seeking for an energetic and collaborat...    3.8
# 2  For more than a decade, Asembia has been worki...    3.6
# 3  Job Description Summary\nThe Information Secur...    3.6
# 4  Magnite is the world's largest independent sel...    3.4
#
#                Company Name            Location        Headquarters  \
# 0  Memorial Sloan-Kettering        New York, NY        New York, NY
# ...

# %%
df_new2 = df_new1.iloc[:,:-3]

# %%
df_new2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12782 entries, 0 to 12781
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          12782 non-null  object
#  1   Salary Estimate    12782 non-null  object
#  2   Job Description    12782 non-null  object
#  3   Rating             12782 non-null  object
#  4   Company Name       12781 non-null  object
#  5   Location           12782 non-null  object
#  6   Headquarters       12782 non-null  object
#  7   Size               12782 non-null  object
#  8   Founded            12782 non-null  object
#  9   Type of ownership  12782 non-null  object
#  10  Industry           12782 non-null  object
#  11  Sector             12782 non-null  object
#  12  Revenue            12782 non-null  object
#  13  Competitors        12382 non-null  object
#  14  page_content       12782 non-null  object
# dtypes: object(15)
# memory usage: 1.5+ MB

# %%
# Create page content column
df_new2['page_content'] = "Job Title: " + df_new2['Job Title'] + "\n" + "Salary Estimate: " + df_new2['Salary Estimate'] + "\n" + "Job Description: " +df_new2['Job Description'] + "\n" +"Rating: " + str(df_new2['Rating']) + "\n" + "Company Name: " + df_new2['Company Name'] + "\n" + "Location: " + df_new2['Location'] + "\n" + "Headquarters: " + df_new2['Headquarters'] + "\n" + "Size: " + df_new2['Size'] + "\n" + "Type of ownership: " + df_new2['Type of ownership'] + "\n" + "Industry: " + df_new2['Industry'] + "\n" + "Sector: " + df_new2['Sector'] + "\n" + "Competitors: " + df_new2["Competitors"]

# %%
df_new2['page_content'][0]
# Out:
# "Job Title: Business Analyst - Clinical & Logistics Platform\nSalary Estimate: $56K-$102K \nJob Description: Company Overview\n\n\nAt Memorial Sloan Kettering (MSK), we’re not only changing the way we treat cancer, but also the way the world thinks about it. By working together and pushing forward with innovation and discovery, we’re driving excellence and improving outcomes. For the 28th year, MSK has been named a top hospital for cancer by U.S. News & World Report. We are proud to be on Becker’s Healthcare list as one of the 150 Great Places to Work in Healthcare in 2018, as well as one of Glassdoor’s Employees’ Choice Best Place to Work for 2018. We’re treating cancer, one patient at a time. Join us and make a difference every day.\n\nJob Description\n\n\nWe are excited to recruit two Business Analyst(s) to join our digital, informatics and technology organization who will measure success on our high priority platforms supported by the Division of Health Informatics. DHI focuses o
# ...

# %%
df_new3 = pd.DataFrame(df_new2['page_content'])

# %%
df_new3.to_csv('data_jobs.csv', index=False)

# %%
df_new2.to_csv('data_jobs2.csv', index=False)

# %%
#pip install -U chromadb langchain

# %%
import pandas as pd

# %%
df_new3 = pd.read_csv('/content/data_jobs_.csv')

# Import DataFrameLoader
from langchain.document_loaders import DataFrameLoader

# Load the documents from the dataframe into docs
# The page content column is 'movie_description'


docs = DataFrameLoader(
            df_new3,
    page_content_column = 'page_content'
).load()

# Print the first 3 documents and the number of documents
docs[:3]
# Out:
# [Document(page_content="Job Title: Business Analyst - Clinical & Logistics Platform\nSalary Estimate: $56K-$102K \nJob Description: Company Overview\n\n\nAt Memorial Sloan Kettering (MSK), we’re not only changing the way we treat cancer, but also the way the world thinks about it. By working together and pushing forward with innovation and discovery, we’re driving excellence and improving outcomes. For the 28th year, MSK has been named a top hospital for cancer by U.S. News & World Report. We are proud to be on Becker’s Healthcare list as one of the 150 Great Places to Work in Healthcare in 2018, as well as one of Glassdoor’s Employees’ Choice Best Place to Work for 2018. We’re treating cancer, one patient at a time. Join us and make a difference every day.\n\nJob Description\n\n\nWe are excited to recruit two Business Analyst(s) to join our digital, informatics and technology organization who will measure success on our high priority platforms supported by the Division of Health Inf
# ...

# %%
#pip install tiktoken==0.5.1

# %%
# Import tiktoken
import tiktoken

# Create the encoder
encoder = tiktoken.get_encoding("cl100k_base")

# Create a list containing the number of tokens for each document
tokens_per_docs = [len(encoder.encode(doc.page_content)) for doc in docs]

#tokens_per_docs
# Show the estimated cost, which is the sum of the amount of tokens divided by 1000, times $0.0001
total_tokens = sum(tokens_per_docs)
cost_per_1000_tokens = 0.0001
cost = (total_tokens / 1000) * cost_per_1000_tokens
cost
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-0a4dd361f7a9> in <cell line: 2>()
#       1 # Import tiktoken
# ----> 2 import tiktoken
#       3
#       4 # Create the encoder
#       5 encoder = tiktoken.get_encoding("cl100k_base")
#
# ModuleNotFoundError: No module named 'tiktoken'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# from chromadb.utils import embedding_functions
# default_ef = embedding_functions.DefaultEmbeddingFunction()
# sentence_transformer_ef = embedding_functions.SentenceTransformerEmbeddingFunction(model_name="all-MiniLM-L6-v2")

# %%
#pip install sentence_transformers

# %%
from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.embeddings.sentence_transformer import (
    SentenceTransformerEmbeddings,
)
from langchain_community.vectorstores import Chroma
from langchain_text_splitters import CharacterTextSplitter

# %%
#import chromadb

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(docs)

# %%
# create the open-source embedding function
embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# ...

# %%
# load it into Chroma
db = Chroma.from_documents(docs, embedding_function,persist_directory='./chroma_db_')

# %%
# persiste the db to disk
db.persist()
#vectordb= None

# %%
import zipfile
import os

def zip_directory(directory_path, output_filename):
    with zipfile.ZipFile(output_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(directory_path):
            for file in files:
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, directory_path)
                zipf.write(file_path, arcname)

# Usage
chroma_db_path = "./chroma_db_"  # Replace with your Chroma DB directory path
output_zip = "chroma_db_compressed_.zip"
zip_directory(chroma_db_path, output_zip)

# %%
from google.colab import files

# Replace 'filename.txt' with the name of your file
files.download('/content/chroma_db_compressed_.zip')

# %%
# Step 1: Decompress the zip file
zip_file_path = "chroma_db_compressed_.zip"
extract_path = "./chroma_db_extracted"

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-cae06c72ba1a> in <cell line: 9>()
#       9 loaded_vectorstore = Chroma(
#      10     persist_directory=extract_path,
# ---> 11     embedding_function=embedding_function
#      12 )
#
# NameError: name 'embedding_function' is not defined

# %%
  # Step 3: Load the Chroma database from the extracted directory
loaded_vectorstore = Chroma(
    persist_directory=extract_path,
    embedding_function=embedding_function
)

# %%
vectordb= None

# %%
# Now we can load the persisted database from disk, and use it as normal.
vectordb = Chroma(persist_directory=vectordb,
                  embedding_function=embedding_function)
# Out:
#   File "<ipython-input-24-64547087161a>", line 3
#     embedding_function=embedding_function, persist_directory='./chroma_db')
#                                            ^
# SyntaxError: keyword argument repeated: persist_directory

# %%
loaded_vectorstore

# %%
retriever = db.as_retriever()
docs = retriever.get_relevant_documents(query)

# %%
# query it
query = "Recommed a company to work as a data scientist in the health sector"
docs = loaded_vectorstore.similarity_search(query, k=1)

# print results
print(docs[0].page_content)
# Out:
# Job Title: Data Scientist
# Salary Estimate: $76K-$122K
# Job Description: Join a thriving company that is changing the way cancer care is delivered for millions of patients around the country. Recently spun off from an internationally renowned research and treatment hospital, AccessHope understands that cancer doesn’t play by the rules, so we don’t either. We are an agile innovative brand that’s backed by a founding member of the National Cancer Center Network. Now, we’re joining forces with employers to bring state-of-the-art cancer expertise to their employees and give patients access to the latest developments in precision medicine, genetic risk assessment and clinical trials, regardless of where they live. The goal? To dramatically improve care, outcomes and value during cancer treatment.
#
# It’s a revolutionary new model – and we’re looking for revolutionary thinkers to join us.
#
# ...

# %%
# query it
query = "Recommed a company to work as a data scientist in the health sector"
docs = vectordb.similarity_search(query, k=1)

# print results
print(docs[:2])
# Out:
# [Document(page_content="Job Title: Data Scientist\nSalary Estimate: $76K-$122K \nJob Description: Join a thriving company that is changing the way cancer care is delivered for millions of patients around the country. Recently spun off from an internationally renowned research and treatment hospital, AccessHope understands that cancer doesn’t play by the rules, so we don’t either. We are an agile innovative brand that’s backed by a founding member of the National Cancer Center Network. Now, we’re joining forces with employers to bring state-of-the-art cancer expertise to their employees and give patients access to the latest developments in precision medicine, genetic risk assessment and clinical trials, regardless of where they live. The goal? To dramatically improve care, outcomes and value during cancer treatment.\n\nIt’s a revolutionary new model – and we’re looking for revolutionary thinkers to join us.\n\nA data scientist is someone who knows how to extract meaning from and inte
# ...

# %%
docs
# Out:
# []

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts.chat import (
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
    SystemMessagePromptTemplate,
)
from langchain_openai import ChatOpenAI

#chat = ChatOpenAI(temperature=0)
from google.colab import userdata
openai_api_key = userdata.get('OPENAI_API_KEY')

chat = ChatOpenAI(model_name="gpt-3.5-turbo", openai_api_key=openai_api_key)

# %%
messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="Hi AI, how are you today?"),
    #ChatPromptTemplate(content="I'm great thank you. How can I help you?"),
    HumanMessage(content="I'd like to understand string theory.")
]

# %%
res = chat(messages)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(

# %%
res.content
# Out:
# 'String theory is a theoretical framework in physics that attempts to explain the fundamental nature of particles and forces in the universe. It proposes that the most basic building blocks of the universe are not point-like particles, as traditionally thought, but rather tiny, vibrating strings. These strings can vibrate at different frequencies, giving rise to different particles and forces.\n\nString theory is still a very active area of research in theoretical physics and has the potential to unify our understanding of the four fundamental forces of nature: gravity, electromagnetism, the weak nuclear force, and the strong nuclear force. However, it is a complex and mathematically demanding theory that has yet to be experimentally confirmed.\n\nIf you have any specific questions about string theory or would like to learn more about a particular aspect of it, feel free to ask!'

# %%
def augment_prompt(query: str):
    results = loaded_vectorstore.similarity_search(query, k=3)
    source_knowledge = "\n".join([x.page_content for x in results])
    augmented_prompt = f"""Using the contexts below, answer the query. If some information is not provided within
the contexts below, do not include, and if the query cannot be answered with the below information, say "I don't know".

Contexts:
{source_knowledge}

Query: {query}"""
    return augmented_prompt

# %%
print(augment_prompt(query))
# Out:
# Using the contexts below, answer the query. If some information is not provided within
# the contexts below, do not include, and if the query cannot be answered with the below information, say "I don't know".
#
# Contexts:
# Job Title: Data Scientist
# Salary Estimate: $76K-$122K
# ...

# %%
prompt = HumanMessage(content=augment_prompt(query))

messages.append(prompt)
res = chat(messages)
print(res.content)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# Based on the provided contexts, I recommend considering Allscripts as a company to work as a data scientist in the health sector. Allscripts is a prominent healthcare technology company based in Whittier, CA, with headquarters in Chicago, IL. They offer a comprehensive platform of clinical, financial, connectivity, and information solutions to enhance collaboration and critical patient information exchange. The company values diversity and equal employment opportunities. With a strong focus on utilizing data to drive integrated care and improve health outcomes, Allscripts provides an innovative and dynamic environment for data scientists in the healthcare sector.

# %%
prompt = HumanMessage(content=augment_prompt("what are the job responsibilities of product data analysts in health sectors"))

messages.append(prompt)
res = chat(messages)
print(res.content)
# Out:
# Based on the provided job descriptions, the job responsibilities of Product Data Analysts in the health sector typically include:
#
# 1. Conducting complex research, analysis, and reporting to support Quality Improvement data needs.
# 2. Collecting, analyzing, and synthesizing data to guide business decision-making for health management, cost of healthcare management, and quality of care.
# 3. Assisting in tracking data files, generating reports, and supporting program applications to meet State and Federal mandates.
# 4. Improving patient care, care coordination, efficiency, and quality while ensuring compliance standards are met.
# 5. Developing technical specifications and executing work plans for analyses.
# 6. Designing and developing analytic reports and data visualizations.
# 7. Understanding and analyzing healthcare claims data to identify trends and patterns.
# 8. Interpreting data analysis results and presenting conclusions to internal teams.
# ...

# %%
for message in messages:
    message.content = message.content[:1000]

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it")
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.16k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/888 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
len(augment_prompt("what are the job responsibilities of product data analysts in health sectors"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e74168961b5f> in <cell line: 1>()
# ----> 1 len(augment_prompt("what are the job responsibilities of product data analysts in health sectors"))
#
# NameError: name 'augment_prompt' is not defined

# %%
input_text =augment_prompt("what are the job responsibilities of product data analysts in health sectors")
input_ids = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(**input_ids,max_new_tokens=1967)
print(tokenizer.decode(outputs[0]))

# %%
# Function to perform web search
def perform_web_search(query):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}
    search_results = ""

    # Glassdoor search
    glassdoor_url = f"https://www.glassdoor.com/Search/results.htm?keyword={query}"
    response = requests.get(glassdoor_url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        glassdoor_results = soup.find_all('div', {'class': 'jobContainer'})
        for result in glassdoor_results[:5]:  # limiting to first 3 results
            title = result.find('a', {'class': 'jobInfoItem jobTitle'}).text.strip() if result.find('a', {'class': 'jobInfoItem jobTitle'}) else 'N/A'
            company = result.find('div', {'class': 'jobInfoItem jobEmpolyerName'}).text.strip() if result.find('div', {'class': 'jobInfoItem jobEmpolyerName'}) else 'N/A'
            location = result.find('span', {'class': 'subtle loc'}).text.strip() if result.find('span', {'class': 'subtle loc'}) else 'N/A'
            search_results += f"Glassdoor Result: {title} at {company}, {location}\n"

    # Indeed search
    indeed_url = f"https://www.indeed.com/jobs?q={query}&limit=10"
    response = requests.get(indeed_url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        indeed_results = soup.find_all('div', {'class': 'jobsearch-SerpJobCard'})
        for result in indeed_results[:5]:  # limiting to first 3 results
            title = result.find('h2', {'class': 'title'}).text.strip() if result.find('h2', {'class': 'title'}) else 'N/A'
            company = result.find('span', {'class': 'company'}).text.strip() if result.find('span', {'class': 'company'}) else 'N/A'
            location = result.find('span', {'class': 'location'}).text.strip() if result.find('span', {'class': 'location'}) else 'N/A'
            search_results += f"Indeed Result: {title} at {company}, {location}\n"

    return search_results

# %%
from bs4 import BeautifulSoup
import requests

# %%
results = perform_web_search("data scientist")

# %%
results
# Out:
# ''
